# %% [markdown]
# # Second Assignment: Create your own ABM

# %% [markdown]
# ## Basic Model

# %%
# Plot a beta distribution with a = 2, b = 5
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import beta
# Parameters for the beta distribution
a = 2
b = 5
# Generate x values from 0 to 1
x = np.linspace(0, 1, 100)
# Calculate the PDF of the beta distribution
y = beta.pdf(x, a, b)
# Create the plot
plt.plot(x, y, '-', label=f'Beta({a}, {b})')
plt.title('Beta Distribution (a=2, b=5)')
plt.xlabel('x')
plt.ylabel('Probability Density')
# Show the plot
plt.show()

# %%
# Set seed for reproducibility
np.random.seed(42)

# Parameters for the log-normal distribution
mean = 3.5  # ln-scale mean
sigma = 0.5  # standard deviation on the log scale

# Generate sample budgets
sample_size = 10000
budgets = np.random.lognormal(mean, sigma, sample_size)

# Plotting
plt.figure(figsize=(8, 5))
plt.hist(budgets, bins=50, color='skyblue', edgecolor='black', density=True)
plt.title('Log-Normal Distribution (mean = 3.5, sigma = 0.5)')
plt.xlabel('Budget (€)')
plt.ylabel('Probability Density')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# Parameters
mu = 0.5
sigma = 0.2
A = 0.15

# Aggressiveness range from 0 to 1
x = np.linspace(0, 1, 500)
increment = A * np.exp(-((x - mu) ** 2) / (2 * sigma ** 2))

# Plotting
plt.figure(figsize=(8, 5))
plt.plot(x, increment, label="Aggression Increment per Drink", color='red')
plt.title("Aggression Increase per Drink vs. Current Aggressiveness")
plt.xlabel("Current Aggressiveness")
plt.ylabel("Aggressiveness Increment")
plt.grid(True)
plt.legend()
plt.show()

# %%
# !streamlit run BasicModel.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.17.94.55:8501
#
#   For better performance, install the Watchdog module:
#
#   $ xcode-select --install
#   $ pip install watchdog
#
# /Users/louisvyvey/Documenten/UGENT/Complexity Economics/Assignment_2/Overpoort/BasicModel.py:100: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(6, 6))
# ^C
#   Stopping...
# Exception ignored in: <module 'threading' from '/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py'>
# Traceback (most recent call last):
# ...

# %% [markdown]
# ## Group Dynamics Model

# %%
# %%writefile GroupDynamics.py
# Out:
# Overwriting Overpoort.py

# %%
# !streamlit run GroupDynamics.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.0.108:8501
#
#   For better performance, install the Watchdog module:
#
#   $ xcode-select --install
#   $ pip install watchdog
#
# 2025-04-03 15:42:36.448 Uncaught app execution
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/exec_code.py", line 121, in exec_func_with_error_handling
#     result = func()
#              ^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/streamlit/runtime/scriptrunner/script_runner.py", line 591, in code_to_exec
#     exec(code, module.__dict__)
#   File "/Users/louisvyvey/Documenten/UGENT/Complexity Economics/Assignment_2/Overpoort.py", line 106, in <module>
#     aggress_threshold = st.sidebar.slider("Aggressiveness Threshold", 0, 1, 0.5)
# ...
